# %%
pip install recordlinkage
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\dogud\anaconda3\envs\karalama\lib\site-packages)

# %%
import pandas as pd
import recordlinkage

# %%
abi = pd.read_excel('data/abi.xlsx')
kba = pd.read_excel('data/kba_updated.xlsx')

# %%
abi.head()
# Out:
#    id_abi Vehicle Type Manufacturer       Model Series  Nominal Start Year  \
# 0       1          Car    SSANGYONG  TIVOLI XLV      1                2016
# 1       2          Car    SSANGYONG  TIVOLI XLV      1                2016
# 2       3          Car    SSANGYONG  TIVOLI XLV      1                2016
# 3       4          Car    SSANGYONG  TIVOLI XLV      1                2016
# 4       5          Car    SSANGYONG  TIVOLI XLV      1                2016
#
#    Production End Year TVI Code  ABI Code Start Date  ... Primary Fuel Type  \
# 0                  NaN   SS2120    104660 2016-09-01  ...            DIESEL
# 1                  NaN   SS2119    104661 2016-09-01  ...            DIESEL
# 2                  NaN   SS2118    104662 2016-09-01  ...            DIESEL
# 3                  NaN   SS2117    104663 2016-09-01  ...            DIESEL
# 4                  NaN   SS2136    104668 2017-03-01  ...            DIESEL
#
# ...

# %%
kba.head()
# Out:
#    id_kba  Manufacturer Identification Number Model Identification Numer  \
# 0   17857                                   1                         96
# 1   17858                                   1                         97
# 2   17859                                   1                        125
# 3   17860                                   1                        148
# 4   17861                                   1                        149
#
#   Vehicle Class  Year of Approval  Month of Approval  Nominal Power  \
# 0             9            1952.0               10.0            4.0
# 1            39            1955.0                5.0            4.0
# 2             9            1955.0                9.0            5.0
# 3            19            1952.0                4.0            7.0
# 4            19            1953.0               12.0            7.0
#
#    Displacement  30 Minutes Nominal Power @ EV  Av. Standing Noise  ...  \
# ...

# %%
indexer = recordlinkage.Index()
indexer.full()
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.
